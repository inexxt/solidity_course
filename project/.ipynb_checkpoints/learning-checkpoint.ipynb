# %%
from web3 import Web3
import json

# %%
w3 = Web3(Web3.HTTPProvider("http://127.0.0.1:8545"))

# %%
w3.eth.blockNumber
# Out:
# 48

# %%
c = lambda x: w3.toChecksumAddress(x)

# %%
from solc import compile_source
from web3.contract import ConciseContract

# %%
# Solidity source code
with open("../project/truffle/build/contracts/StateChannel.json", "r") as f:
    contract_data = json.load(f)

# %%
address = contract_data["networks"]
contra
# Out:
# {'abi': [{'constant': True,
#    'inputs': [],
#    'name': 'PUNISHMENT',
#    'outputs': [{'name': '', 'type': 'uint256'}],
#    'payable': False,
#    'stateMutability': 'view',
#    'type': 'function'},
#   {'constant': True,
#    'inputs': [],
#    'name': 'accepting_new_channels',
#    'outputs': [{'name': '', 'type': 'bool'}],
#    'payable': False,
#    'stateMutability': 'view',
#    'type': 'function'},
#   {'constant': True,
#    'inputs': [],
#    'name': 'WAITING_PERIOD',
#    'outputs': [{'name': '', 'type': 'uint256'}],
#    'payable': False,
#    'stateMutability': 'view',
#    'type': 'function'},
#   {'constant': False,
#    'inputs': [],
#    'name': 'renounceOwnership',
#    'outputs': [],
#    'payable': False,
#    'stateMutability': 'nonpayable',
#    'type': 'function'},
#   {'constant': True,
#    'inputs': [],
#    'name': 'owner',
#    'outputs': [{'name': '', 'type': 'address'}],
#    'payable': False,
#    'stateMutability': 'view',
#    'type': 'function'},
#   {'constant': False,
#    'inputs': [{'name': 'newOwner', 'type': 'address'}],
#    'name': 'transferOwnership',
#    'outputs': [],
#    'payable': False,
#    'stateMutability': 'nonpayable',
#    'type': 'function'},
#   {'inputs': [{'name': '_accepting_new_channels', 'type': 'bool'}],
#    'payable': True,
#    'stateMutability': 'payable',
#    'type': 'constructor'},
#   {'anonymous': False,
#    'inputs': [{'indexed': False, 'name': 'user', 'type': 'address'},
#     {'indexed': False, 'name': 'channel_number', 'type': 'uint256'},
#     {'indexed': False, 'name': 'cap', 'type': 'uint256'}],
#    'name': 'CreatedChannel',
#    'type': 'event'},
#   {'anonymous': False,
#    'inputs': [{'indexed': True, 'name': 'previousOwner', 'type': 'address'}],
#    'name': 'OwnershipRenounced',
#    'type': 'event'},
#   {'anonymous': False,
#    'inputs': [{'indexed': True, 'name': 'previousOwner', 'type': 'address'},
#     {'indexed': True, 'name': 'newOwner', 'type': 'address'}],
#    'name': 'OwnershipTransferred',
#    'type': 'event'},
#   {'constant': False,
#    'inputs': [{'name': '_accepting_new_channels', 'type': 'bool'}],
#    'name': 'changeAcceptanceStatus',
#    'outputs': [],
#    'payable': False,
#    'stateMutability': 'nonpayable',
#    'type': 'function'},
#   {'constant': False,
#    'inputs': [{'name': 'cap', 'type': 'uint256'}],
#    'name': 'createNewChannel',
#    'outputs': [{'name': '', 'type': 'uint256'}],
#    'payable': True,
#    'stateMutability': 'payable',
#    'type': 'function'},
#   {'constant': False,
#    'inputs': [{'name': 'channel_number', 'type': 'uint256'},
#     {'name': 'funds_used', 'type': 'uint256'}],
#    'name': 'startClosingByUser',
#    'outputs': [],
#    'payable': False,
#    'stateMutability': 'nonpayable',
#    'type': 'function'},
#   {'constant': False,
#    'inputs': [{'name': 'user', 'type': 'address'},
#     {'name': 'channel_number', 'type': 'uint256'},
#     {'name': 'funds_used', 'type': 'uint256'},
#     {'name': 'v', 'type': 'uint8'},
#     {'name': 'r', 'type': 'bytes32'},
#     {'name': 's', 'type': 'bytes32'}],
#    'name': 'closeByOwner',
#    'outputs': [],
#    'payable': False,
#    'stateMutability': 'nonpayable',
#    'type': 'function'},
#   {'constant': False,
#    'inputs': [{'name': 'user', 'type': 'address'},
#     {'name': 'channel_number', 'type': 'uint256'},
#     {'name': 'funds_used', 'type': 'uint256'},
#     {'name': 'v', 'type': 'uint8'},
#     {'name': 'r', 'type': 'bytes32'},
#     {'name': 's', 'type': 'bytes32'}],
#    'name': 'challengeByOwner',
#    'outputs': [],
#    'payable': False,
#    'stateMutability': 'nonpayable',
#    'type': 'function'},
#   {'constant': False,
#    'inputs': [{'name': 'channel_number', 'type': 'uint256'}],
#    'name': 'closeByUser',
#    'outputs': [],
#    'payable': False,
#    'stateMutability': 'nonpayable',
#    'type': 'function'},
#   {'constant': True,
#    'inputs': [{'name': 'funds_used', 'type': 'uint256'},
#     {'name': 'user', 'type': 'address'},
#     {'name': 'channel_number', 'type': 'uint256'},
#     {'name': 'v', 'type': 'uint8'},
#     {'name': 'r', 'type': 'bytes32'},
#     {'name': 's', 'type': 'bytes32'}],
#    'name': 'verifyReceipt',
#    'outputs': [{'name': '', 'type': 'bool'}],
#    'payable': False,
#    'stateMutability': 'view',
#    'type': 'function'},
#   {'constant': True,
#    'inputs': [{'name': 'funds_used', 'type': 'uint256'},
#     {'name': 'user', 'type': 'uint256'},
#     {'name': 'channel_number', 'type': 'uint256'}],
#    'name': 'hash',
#    'outputs': [{'name': '', 'type': 'bytes32'}],
#    'payable': False,
#    'stateMutability': 'pure',
#    'type': 'function'},
#   {'constant': True,
#    'inputs': [{'name': 'message', 'type': 'bytes32'},
#     {'name': 'v', 'type': 'uint8'},
#     {'name': 'r', 'type': 'bytes32'},
#     {'name': 's', 'type': 'bytes32'}],
#    'name': 'verify',
#    'outputs': [{'name': '', 'type': 'address'}],
#    'payable': False,
#    'stateMutability': 'pure',
#    'type': 'function'}],
#  'ast': {'absolutePath': '/home/jack/eth_labs/code/project/truffle/contracts/StateChannel.sol',
#   'exportedSymbols': {'StateChannel': [726]},
#   'id': 727,
#   'nodeType': 'SourceUnit',
#   'nodes': [{'id': 228,
#     'literals': ['solidity', '^', '0.4', '.23'],
#     'nodeType': 'PragmaDirective',
#     'src': '0:24:3'},
#    {'absolutePath': '/home/jack/eth_labs/code/project/truffle/contracts/Ownable.sol',
#     'file': './Ownable.sol',
#     'id': 229,
#     'nodeType': 'ImportDirective',
#     'scope': 727,
#     'sourceUnit': 133,
#     'src': '221:23:3',
#     'symbolAliases': [],
#     'unitAlias': ''},
#    {'absolutePath': '/home/jack/eth_labs/code/project/truffle/contracts/SafeMath.sol',
#     'file': './SafeMath.sol',
#     'id': 230,
#     'nodeType': 'ImportDirective',
#     'scope': 727,
#     'sourceUnit': 227,
#     'src': '245:24:3',
#     'symbolAliases': [],
#     'unitAlias': ''},
#    {'baseContracts': [{'arguments': None,
#       'baseName': {'contractScope': None,
#        'id': 231,
#        'name': 'Ownable',
#        'nodeType': 'UserDefinedTypeName',
#        'referencedDeclaration': 132,
#        'src': '297:7:3',
#        'typeDescriptions': {'typeIdentifier': 't_contract$_Ownable_$132',
#         'typeString': 'contract Ownable'}},
#       'id': 232,
#       'nodeType': 'InheritanceSpecifier',
#       'src': '297:7:3'}],
#     'contractDependencies': [132],
#     'contractKind': 'contract',
#     'documentation': None,
#     'fullyImplemented': True,
#     'id': 726,
#     'linearizedBaseContracts': [726, 132],
#     'name': 'StateChannel',
#     'nodeType': 'ContractDefinition',
#     'nodes': [{'id': 235,
#       'libraryName': {'contractScope': None,
#        'id': 233,
#        'name': 'SafeMath',
#        'nodeType': 'UserDefinedTypeName',
#        'referencedDeclaration': 226,
#        'src': '315:8:3',
#        'typeDescriptions': {'typeIdentifier': 't_contract$_SafeMath_$226',
#         'typeString': 'library SafeMath'}},
#       'nodeType': 'UsingForDirective',
#       'src': '309:27:3',
#       'typeName': {'id': 234,
#        'name': 'uint256',
#        'nodeType': 'ElementaryTypeName',
#        'src': '328:7:3',
#        'typeDescriptions': {'typeIdentifier': 't_uint256',
#         'typeString': 'uint256'}}},
#      {'constant': True,
#       'id': 238,
#       'name': 'PUNISHMENT',
#       'nodeType': 'VariableDeclaration',
#       'scope': 726,
#       'src': '350:44:3',
#       'stateVariable': True,
#       'storageLocation': 'default',
#       'typeDescriptions': {'typeIdentifier': 't_uint256',
#        'typeString': 'uint256'},
#       'typeName': {'id': 236,
#        'name': 'uint256',
#        'nodeType': 'ElementaryTypeName',
#        'src': '350:7:3',
#        'typeDescriptions': {'typeIdentifier': 't_uint256',
#         'typeString': 'uint256'}},
#       'value': {'argumentTypes': None,
#        'hexValue': '31',
#        'id': 237,
#        'isConstant': False,
#        'isLValue': False,
#        'isPure': True,
#        'kind': 'number',
#        'lValueRequested': False,
#        'nodeType': 'Literal',
#        'src': '387:7:3',
#        'subdenomination': 'ether',
#        'typeDescriptions': {'typeIdentifier': 't_rational_1000000000000000000_by_1',
#         'typeString': 'int_const 1000000000000000000'},
#        'value': '1'},
#       'visibility': 'public'},
#      {'constant': True,
#       'id': 241,
#       'name': 'WAITING_PERIOD',
#       'nodeType': 'VariableDeclaration',
#       'scope': 726,
#       'src': '492:42:3',
#       'stateVariable': True,
#       'storageLocation': 'default',
#       'typeDescriptions': {'typeIdentifier': 't_uint256',
#        'typeString': 'uint256'},
#       'typeName': {'id': 239,
#        'name': 'uint256',
#        'nodeType': 'ElementaryTypeName',
#        'src': '492:7:3',
#        'typeDescriptions': {'typeIdentifier': 't_uint256',
#         'typeString': 'uint256'}},
#       'value': {'argumentTypes': None,
#        'hexValue': '33',
#        'id': 240,
#        'isConstant': False,
#        'isLValue': False,
#        'isPure': True,
#        'kind': 'number',
#        'lValueRequested': False,
#        'nodeType': 'Literal',
#        'src': '533:1:3',
#        'subdenomination': None,
#        'typeDescriptions': {'typeIdentifier': 't_rational_3_by_1',
#         'typeString': 'int_const 3'},
#        'value': '3'},
#       'visibility': 'public'},
#      {'constant': False,
#       'id': 244,
#       'name': 'accepting_new_channels',
#       'nodeType': 'VariableDeclaration',
#       'scope': 726,
#       'src': '662:41:3',
#       'stateVariable': True,
#       'storageLocation': 'default',
#       'typeDescriptions': {'typeIdentifier': 't_bool', 'typeString': 'bool'},
#       'typeName': {'id': 242,
#        'name': 'bool',
#        'nodeType': 'ElementaryTypeName',
#        'src': '662:4:3',
#        'typeDescriptions': {'typeIdentifier': 't_bool', 'typeString': 'bool'}},
#       'value': {'argumentTypes': None,
#        'hexValue': '74727565',
#        'id': 243,
#        'isConstant': False,
#        'isLValue': False,
#        'isPure': True,
#        'kind': 'bool',
#        'lValueRequested': False,
#        'nodeType': 'Literal',
#        'src': '699:4:3',
#        'subdenomination': None,
#        'typeDescriptions': {'typeIdentifier': 't_bool', 'typeString': 'bool'},
#        'value': 'true'},
#       'visibility': 'public'},
#      {'canonicalName': 'StateChannel.Stage',
#       'id': 248,
#       'members': [{'id': 245,
#         'name': 'Open',
#         'nodeType': 'EnumValue',
#         'src': '731:4:3'},
#        {'id': 246,
#         'name': 'WaitingForChallengeByOwner',
#         'nodeType': 'EnumValue',
#         'src': '745:26:3'},
#        {'id': 247,
#         'name': 'Closed',
#         'nodeType': 'EnumValue',
#         'src': '781:6:3'}],
#       'name': 'Stage',
#       'nodeType': 'EnumDefinition',
#       'src': '710:83:3'},
#      {'canonicalName': 'StateChannel.StateS',
#       'id': 257,
#       'members': [{'constant': False,
#         'id': 250,
#         'name': 'stage',
#         'nodeType': 'VariableDeclaration',
#         'scope': 257,
#         'src': '823:11:3',
#         'stateVariable': False,
#         'storageLocation': 'default',
#         'typeDescriptions': {'typeIdentifier': 't_enum$_Stage_$248',
#          'typeString': 'enum StateChannel.Stage'},
#         'typeName': {'contractScope': None,
#          'id': 249,
#          'name': 'Stage',
#          'nodeType': 'UserDefinedTypeName',
#          'referencedDeclaration': 248,
#          'src': '823:5:3',
#          'typeDescriptions': {'typeIdentifier': 't_enum$_Stage_$248',
#           'typeString': 'enum StateChannel.Stage'}},
#         'value': None,
#         'visibility': 'internal'},
#        {'constant': False,
#         'id': 252,
#         'name': 'cap',
#         'nodeType': 'VariableDeclaration',
#         'scope': 257,
#         'src': '844:11:3',
#         'stateVariable': False,
#         'storageLocation': 'default',
#         'typeDescriptions': {'typeIdentifier': 't_uint256',
#          'typeString': 'uint256'},
#         'typeName': {'id': 251,
#          'name': 'uint256',
#          'nodeType': 'ElementaryTypeName',
#          'src': '844:7:3',
#          'typeDescriptions': {'typeIdentifier': 't_uint256',
#           'typeString': 'uint256'}},
#         'value': None,
#         'visibility': 'internal'},
#        {'constant': False,
#         'id': 254,
#         'name': 'closed_at',
#         'nodeType': 'VariableDeclaration',
#         'scope': 257,
#         'src': '865:17:3',
#         'stateVariable': False,
#         'storageLocation': 'default',
#         'typeDescriptions': {'typeIdentifier': 't_uint256',
#          'typeString': 'uint256'},
#         'typeName': {'id': 253,
#          'name': 'uint256',
#          'nodeType': 'ElementaryTypeName',
#          'src': '865:7:3',
#          'typeDescriptions': {'typeIdentifier': 't_uint256',
#           'typeString': 'uint256'}},
#         'value': None,
#         'visibility': 'internal'},
#        {'constant': False,
#         'id': 256,
#         'name': 'funds_used',
#         'nodeType': 'VariableDeclaration',
#         'scope': 257,
#         'src': '892:18:3',
#         'stateVariable': False,
#         'storageLocation': 'default',
#         'typeDescriptions': {'typeIdentifier': 't_uint256',
#          'typeString': 'uint256'},
#         'typeName': {'id': 255,
#          'name': 'uint256',
#          'nodeType': 'ElementaryTypeName',
#          'src': '892:7:3',
#          'typeDescriptions': {'typeIdentifier': 't_uint256',
#           'typeString': 'uint256'}},
#         'value': None,
#         'visibility': 'internal'}],
#       'name': 'StateS',
#       'nodeType': 'StructDefinition',
#       'scope': 726,
#       'src': '799:118:3',
#       'visibility': 'public'},
#      {'constant': False,
#       'id': 261,
#       'name': 'available_channel',
#       'nodeType': 'VariableDeclaration',
#       'scope': 726,
#       'src': '923:46:3',
#       'stateVariable': True,
#       'storageLocation': 'default',
#       'typeDescriptions': {'typeIdentifier': 't_mapping$_t_address_$_t_uint256_$',
#        'typeString': 'mapping(address => uint256)'},
#       'typeName': {'id': 260,
#        'keyType': {'id': 258,
#         'name': 'address',
#         'nodeType': 'ElementaryTypeName',
#         'src': '932:7:3',
#         'typeDescriptions': {'typeIdentifier': 't_address',
#          'typeString': 'address'}},
#        'nodeType': 'Mapping',
#        'src': '923:28:3',
#        'typeDescriptions': {'typeIdentifier': 't_mapping$_t_address_$_t_uint256_$',
#         'typeString': 'mapping(address => uint256)'},
#        'valueType': {'id': 259,
#         'name': 'uint256',
#         'nodeType': 'ElementaryTypeName',
#         'src': '943:7:3',
#         'typeDescriptions': {'typeIdentifier': 't_uint256',
#          'typeString': 'uint256'}}},
#       'value': None,
#       'visibility': 'internal'},
#      {'constant': False,
#       'id': 267,
#       'name': 'state',
#       'nodeType': 'VariableDeclaration',
#       'scope': 726,
#       'src': '1069:54:3',
#       'stateVariable': True,
#       'storageLocation': 'default',
#       'typeDescriptions': {'typeIdentifier': 't_mapping$_t_address_$_t_mapping$_t_uint256_$_t_struct$_StateS_$257_storage_$_$',
#        'typeString': 'mapping(address => mapping(uint256 => struct StateChannel.StateS))'},
#       'typeName': {'id': 266,
#        'keyType': {'id': 262,
#         'name': 'address',
#         'nodeType': 'ElementaryTypeName',
#         'src': '1078:7:3',
#         'typeDescriptions': {'typeIdentifier': 't_address',
#          'typeString': 'address'}},
#        'nodeType': 'Mapping',
#        'src': '1069:48:3',
#        'typeDescriptions': {'typeIdentifier': 't_mapping$_t_address_$_t_mapping$_t_uint256_$_t_struct$_StateS_$257_storage_$_$',
#         'typeString': 'mapping(address => mapping(uint256 => struct StateChannel.StateS))'},
#        'valueType': {'id': 265,
#         'keyType': {'id': 263,
#          'name': 'uint256',
#          'nodeType': 'ElementaryTypeName',
#          'src': '1098:7:3',
#          'typeDescriptions': {'typeIdentifier': 't_uint256',
#           'typeString': 'uint256'}},
#         'nodeType': 'Mapping',
#         'src': '1089:27:3',
#         'typeDescriptions': {'typeIdentifier': 't_mapping$_t_uint256_$_t_struct$_StateS_$257_storage_$',
#          'typeString': 'mapping(uint256 => struct StateChannel.StateS)'},
#         'valueType': {'contractScope': None,
#          'id': 264,
#          'name': 'StateS',
#          'nodeType': 'UserDefinedTypeName',
#          'referencedDeclaration': 257,
#          'src': '1109:6:3',
#          'typeDescriptions': {'typeIdentifier': 't_struct$_StateS_$257_storage_ptr',
#           'typeString': 'struct StateChannel.StateS'}}}},
#       'value': None,
#       'visibility': 'internal'},
#      {'anonymous': False,
#       'documentation': None,
#       'id': 275,
#       'name': 'CreatedChannel',
#       'nodeType': 'EventDefinition',
#       'parameters': {'id': 274,
#        'nodeType': 'ParameterList',
#        'parameters': [{'constant': False,
#          'id': 269,
#          'indexed': False,
#          'name': 'user',
#          'nodeType': 'VariableDeclaration',
#          'scope': 275,
#          'src': '1243:12:3',
#          'stateVariable': False,
#          'storageLocation': 'default',
#          'typeDescriptions': {'typeIdentifier': 't_address',
#           'typeString': 'address'},
#          'typeName': {'id': 268,
#           'name': 'address',
#           'nodeType': 'ElementaryTypeName',
#           'src': '1243:7:3',
#           'typeDescriptions': {'typeIdentifier': 't_address',
#            'typeString': 'address'}},
#          'value': None,
#          'visibility': 'internal'},
#         {'constant': False,
#          'id': 271,
#          'indexed': False,
#          'name': 'channel_number',
#          'nodeType': 'VariableDeclaration',
#          'scope': 275,
#          'src': '1257:22:3',
#          'stateVariable': False,
#          'storageLocation': 'default',
#          'typeDescriptions': {'typeIdentifier': 't_uint256',
#           'typeString': 'uint256'},
#          'typeName': {'id': 270,
#           'name': 'uint256',
#           'nodeType': 'ElementaryTypeName',
#           'src': '1257:7:3',
#           'typeDescriptions': {'typeIdentifier': 't_uint256',
#            'typeString': 'uint256'}},
#          'value': None,
#          'visibility': 'internal'},
#         {'constant': False,
#          'id': 273,
#          'indexed': False,
#          'name': 'cap',
#          'nodeType': 'VariableDeclaration',
#          'scope': 275,
#          'src': '1281:11:3',
#          'stateVariable': False,
#          'storageLocation': 'default',
#          'typeDescriptions': {'typeIdentifier': 't_uint256',
#           'typeString': 'uint256'},
#          'typeName': {'id': 272,
#           'name': 'uint256',
#           'nodeType': 'ElementaryTypeName',
#           'src': '1281:7:3',
#           'typeDescriptions': {'typeIdentifier': 't_uint256',
#            'typeString': 'uint256'}},
#          'value': None,
#          'visibility': 'internal'}],
#        'src': '1242:51:3'},
#       'src': '1222:72:3'},
#      {'body': {'id': 284,
#        'nodeType': 'Block',
#        'src': '1357:64:3',
#        'statements': [{'expression': {'argumentTypes': None,
#           'arguments': [{'argumentTypes': None,
#             'id': 281,
#             'name': '_accepting_new_channels',
#             'nodeType': 'Identifier',
#             'overloadedDeclarations': [],
#             'referencedDeclaration': 277,
#             'src': '1390:23:3',
#             'typeDescriptions': {'typeIdentifier': 't_bool',
#              'typeString': 'bool'}}],
#           'expression': {'argumentTypes': [{'typeIdentifier': 't_bool',
#              'typeString': 'bool'}],
#            'id': 280,
#            'name': 'changeAcceptanceStatus',
#            'nodeType': 'Identifier',
#            'overloadedDeclarations': [],
#            'referencedDeclaration': 297,
#            'src': '1367:22:3',
#            'typeDescriptions': {'typeIdentifier': 't_function_internal_nonpayable$_t_bool_$returns$__$',
#             'typeString': 'function (bool)'}},
#           'id': 282,
#           'isConstant': False,
#           'isLValue': False,
#           'isPure': False,
#           'kind': 'functionCall',
#           'lValueRequested': False,
#           'names': [],
#           'nodeType': 'FunctionCall',
#           'src': '1367:47:3',
#           'typeDescriptions': {'typeIdentifier': 't_tuple$__$',
#            'typeString': 'tuple()'}},
#          'id': 283,
#          'nodeType': 'ExpressionStatement',
#          'src': '1367:47:3'}]},
#       'documentation': None,
#       'id': 285,
#       'implemented': True,
#       'isConstructor': True,
#       'isDeclaredConst': False,
#       'modifiers': [],
#       'name': '',
#       'nodeType': 'FunctionDefinition',
#       'parameters': {'id': 278,
#        'nodeType': 'ParameterList',
#        'parameters': [{'constant': False,
#          'id': 277,
#          'name': '_accepting_new_channels',
#          'nodeType': 'VariableDeclaration',
#          'scope': 285,
#          'src': '1312:28:3',
#          'stateVariable': False,
#          'storageLocation': 'default',
#          'typeDescriptions': {'typeIdentifier': 't_bool',
#           'typeString': 'bool'},
#          'typeName': {'id': 276,
#           'name': 'bool',
#           'nodeType': 'ElementaryTypeName',
#           'src': '1312:4:3',
#           'typeDescriptions': {'typeIdentifier': 't_bool',
#            'typeString': 'bool'}},
#          'value': None,
#          'visibility': 'internal'}],
#        'src': '1311:30:3'},
#       'payable': True,
#       'returnParameters': {'id': 279,
#        'nodeType': 'ParameterList',
#        'parameters': [],
#        'src': '1357:0:3'},
#       'scope': 726,
#       'src': '1300:121:3',
#       'stateMutability': 'payable',
#       'superFunction': None,
#       'visibility': 'public'},
#      {'body': {'id': 296,
#        'nodeType': 'Block',
#        'src': '1506:65:3',
#        'statements': [{'expression': {'argumentTypes': None,
#           'id': 294,
#           'isConstant': False,
#           'isLValue': False,
#           'isPure': False,
#           'lValueRequested': False,
#           'leftHandSide': {'argumentTypes': None,
#            'id': 292,
#            'name': 'accepting_new_channels',
#            'nodeType': 'Identifier',
#            'overloadedDeclarations': [],
#            'referencedDeclaration': 244,
#            'src': '1516:22:3',
#            'typeDescriptions': {'typeIdentifier': 't_bool',
#             'typeString': 'bool'}},
#           'nodeType': 'Assignment',
#           'operator': '=',
#           'rightHandSide': {'argumentTypes': None,
#            'id': 293,
#            'name': '_accepting_new_channels',
#            'nodeType': 'Identifier',
#            'overloadedDeclarations': [],
#            'referencedDeclaration': 287,
#            'src': '1541:23:3',
#            'typeDescriptions': {'typeIdentifier': 't_bool',
#             'typeString': 'bool'}},
#           'src': '1516:48:3',
#           'typeDescriptions': {'typeIdentifier': 't_bool',
#            'typeString': 'bool'}},
#          'id': 295,
#          'nodeType': 'ExpressionStatement',
#          'src': '1516:48:3'}]},
#       'documentation': None,
#       'id': 297,
#       'implemented': True,
#       'isConstructor': False,
#       'isDeclaredConst': False,
#       'modifiers': [{'arguments': None,
#         'id': 290,
#         'modifierName': {'argumentTypes': None,
#          'id': 289,
#          'name': 'onlyOwner',
#          'nodeType': 'Identifier',
#          'overloadedDeclarations': [],
#          'referencedDeclaration': 90,
#          'src': '1496:9:3',
#          'typeDescriptions': {'typeIdentifier': 't_modifier$__$',
#           'typeString': 'modifier ()'}},
#         'nodeType': 'ModifierInvocation',
#         'src': '1496:9:3'}],
#       'name': 'changeAcceptanceStatus',
#       'nodeType': 'FunctionDefinition',
#       'parameters': {'id': 288,
#        'nodeType': 'ParameterList',
#        'parameters': [{'constant': False,
#          'id': 287,
#          'name': '_accepting_new_channels',
#          'nodeType': 'VariableDeclaration',
#          'scope': 297,
#          'src': '1459:28:3',
#          'stateVariable': False,
#          'storageLocation': 'default',
#          'typeDescriptions': {'typeIdentifier': 't_bool',
#           'typeString': 'bool'},
#          'typeName': {'id': 286,
#           'name': 'bool',
#           'nodeType': 'ElementaryTypeName',
#           'src': '1459:4:3',
#           'typeDescriptions': {'typeIdentifier': 't_bool',
#            'typeString': 'bool'}},
#          'value': None,
#          'visibility': 'internal'}],
#        'src': '1458:30:3'},
#       'payable': False,
#       'returnParameters': {'id': 291,
#        'nodeType': 'ParameterList',
#        'parameters': [],
#        'src': '1506:0:3'},
#       'scope': 726,
#       'src': '1427:144:3',
#       'stateMutability': 'nonpayable',
#       'superFunction': None,
#       'visibility': 'public'},
#      {'body': {'id': 354,
#        'nodeType': 'Block',
#        'src': '1648:493:3',
#        'statements': [{'expression': {'argumentTypes': None,
#           'arguments': [{'argumentTypes': None,
#             'commonType': {'typeIdentifier': 't_uint256',
#              'typeString': 'uint256'},
#             'id': 311,
#             'isConstant': False,
#             'isLValue': False,
#             'isPure': False,
#             'lValueRequested': False,
#             'leftExpression': {'argumentTypes': None,
#              'expression': {'argumentTypes': None,
#               'id': 305,
#               'name': 'msg',
#               'nodeType': 'Identifier',
#               'overloadedDeclarations': [],
#               'referencedDeclaration': 741,
#               'src': '1667:3:3',
#               'typeDescriptions': {'typeIdentifier': 't_magic_message',
#                'typeString': 'msg'}},
#              'id': 306,
#              'isConstant': False,
#              'isLValue': False,
#              'isPure': False,
#              'lValueRequested': False,
#              'memberName': 'value',
#              'nodeType': 'MemberAccess',
#              'referencedDeclaration': None,
#              'src': '1667:9:3',
#              'typeDescriptions': {'typeIdentifier': 't_uint256',
#               'typeString': 'uint256'}},
#             'nodeType': 'BinaryOperation',
#             'operator': '==',
#             'rightExpression': {'argumentTypes': None,
#              'components': [{'argumentTypes': None,
#                'commonType': {'typeIdentifier': 't_uint256',
#                 'typeString': 'uint256'},
#                'id': 309,
#                'isConstant': False,
#                'isLValue': False,
#                'isPure': False,
#                'lValueRequested': False,
#                'leftExpression': {'argumentTypes': None,
#                 'id': 307,
#                 'name': 'cap',
#                 'nodeType': 'Identifier',
#                 'overloadedDeclarations': [],
#                 'referencedDeclaration': 299,
#                 'src': '1681:3:3',
#                 'typeDescriptions': {'typeIdentifier': 't_uint256',
#                  'typeString': 'uint256'}},
#                'nodeType': 'BinaryOperation',
#                'operator': '+',
#                'rightExpression': {'argumentTypes': None,
#                 'id': 308,
#                 'name': 'PUNISHMENT',
#                 'nodeType': 'Identifier',
#                 'overloadedDeclarations': [],
#                 'referencedDeclaration': 238,
#                 'src': '1687:10:3',
#                 'typeDescriptions': {'typeIdentifier': 't_uint256',
#                  'typeString': 'uint256'}},
#                'src': '1681:16:3',
#                'typeDescriptions': {'typeIdentifier': 't_uint256',
#                 'typeString': 'uint256'}}],
#              'id': 310,
#              'isConstant': False,
#              'isInlineArray': False,
#              'isLValue': False,
#              'isPure': False,
#              'lValueRequested': False,
#              'nodeType': 'TupleExpression',
#              'src': '1680:18:3',
#              'typeDescriptions': {'typeIdentifier': 't_uint256',
#               'typeString': 'uint256'}},
#             'src': '1667:31:3',
#             'typeDescriptions': {'typeIdentifier': 't_bool',
#              'typeString': 'bool'}}],
#           'expression': {'argumentTypes': [{'typeIdentifier': 't_bool',
#              'typeString': 'bool'}],
#            'id': 304,
#            'name': 'require',
#            'nodeType': 'Identifier',
#            'overloadedDeclarations': [744, 745],
#            'referencedDeclaration': 744,
#            'src': '1658:7:3',
#            'typeDescriptions': {'typeIdentifier': 't_function_require_pure$_t_bool_$returns$__$',
#             'typeString': 'function (bool) pure'}},
#           'id': 312,
#           'isConstant': False,
#           'isLValue': False,
#           'isPure': False,
#           'kind': 'functionCall',
#           'lValueRequested': False,
#           'names': [],
#           'nodeType': 'FunctionCall',
#           'src': '1658:41:3',
#           'typeDescriptions': {'typeIdentifier': 't_tuple$__$',
#            'typeString': 'tuple()'}},
#          'id': 313,
#          'nodeType': 'ExpressionStatement',
#          'src': '1658:41:3'},
#         {'assignments': [315],
#          'declarations': [{'constant': False,
#            'id': 315,
#            'name': 'channel_number',
#            'nodeType': 'VariableDeclaration',
#            'scope': 355,
#            'src': '1755:22:3',
#            'stateVariable': False,
#            'storageLocation': 'default',
#            'typeDescriptions': {'typeIdentifier': 't_uint256',
#             'typeString': 'uint256'},
#            'typeName': {'id': 314,
#             'name': 'uint256',
#             'nodeType': 'ElementaryTypeName',
#             'src': '1755:7:3',
#             'typeDescriptions': {'typeIdentifier': 't_uint256',
#              'typeString': 'uint256'}},
#            'value': None,
#            'visibility': 'internal'}],
#          'id': 320,
#          'initialValue': {'argumentTypes': None,
#           'baseExpression': {'argumentTypes': None,
#            'id': 316,
#            'name': 'available_channel',
#            'nodeType': 'Identifier',
#            'overloadedDeclarations': [],
#            'referencedDeclaration': 261,
#            'src': '1780:17:3',
#            'typeDescriptions': {'typeIdentifier': 't_mapping$_t_address_$_t_uint256_$',
#             'typeString': 'mapping(address => uint256)'}},
#           'id': 319,
#           'indexExpression': {'argumentTypes': None,
#            'expression': {'argumentTypes': None,
#             'id': 317,
#             'name': 'msg',
#             'nodeType': 'Identifier',
#             'overloadedDeclarations': [],
#             'referencedDeclaration': 741,
#             'src': '1798:3:3',
#             'typeDescriptions': {'typeIdentifier': 't_magic_message',
#              'typeString': 'msg'}},
#            'id': 318,
#            'isConstant': False,
#            'isLValue': False,
#            'isPure': False,
#            'lValueRequested': False,
#            'memberName': 'sender',
#            'nodeType': 'MemberAccess',
#            'referencedDeclaration': None,
#            'src': '1798:10:3',
#            'typeDescriptions': {'typeIdentifier': 't_address',
#             'typeString': 'address'}},
#           'isConstant': False,
#           'isLValue': True,
#           'isPure': False,
#           'lValueRequested': False,
#           'nodeType': 'IndexAccess',
#           'src': '1780:29:3',
#           'typeDescriptions': {'typeIdentifier': 't_uint256',
#            'typeString': 'uint256'}},
#          'nodeType': 'VariableDeclarationStatement',
#          'src': '1755:54:3'},
#         {'expression': {'argumentTypes': None,
#           'id': 328,
#           'isConstant': False,
#           'isLValue': False,
#           'isPure': False,
#           'lValueRequested': False,
#           'leftHandSide': {'argumentTypes': None,
#            'baseExpression': {'argumentTypes': None,
#             'id': 321,
#             'name': 'available_channel',
#             'nodeType': 'Identifier',
#             'overloadedDeclarations': [],
#             'referencedDeclaration': 261,
#             'src': '1819:17:3',
#             'typeDescriptions': {'typeIdentifier': 't_mapping$_t_address_$_t_uint256_$',
#              'typeString': 'mapping(address => uint256)'}},
#            'id': 324,
#            'indexExpression': {'argumentTypes': None,
#             'expression': {'argumentTypes': None,
#              'id': 322,
#              'name': 'msg',
#              'nodeType': 'Identifier',
#              'overloadedDeclarations': [],
#              'referencedDeclaration': 741,
#              'src': '1837:3:3',
#              'typeDescriptions': {'typeIdentifier': 't_magic_message',
#               'typeString': 'msg'}},
#             'id': 323,
#             'isConstant': False,
#             'isLValue': False,
#             'isPure': False,
#             'lValueRequested': False,
#             'memberName': 'sender',
#             'nodeType': 'MemberAccess',
#             'referencedDeclaration': None,
#             'src': '1837:10:3',
#             'typeDescriptions': {'typeIdentifier': 't_address',
#              'typeString': 'address'}},
#            'isConstant': False,
#            'isLValue': True,
#            'isPure': False,
#            'lValueRequested': True,
#            'nodeType': 'IndexAccess',
#            'src': '1819:29:3',
#            'typeDescriptions': {'typeIdentifier': 't_uint256',
#             'typeString': 'uint256'}},
#           'nodeType': 'Assignment',
#           'operator': '=',
#           'rightHandSide': {'argumentTypes': None,
#            'commonType': {'typeIdentifier': 't_uint256',
#             'typeString': 'uint256'},
#            'id': 327,
#            'isConstant': False,
#            'isLValue': False,
#            'isPure': False,
#            'lValueRequested': False,
#            'leftExpression': {'argumentTypes': None,
#             'id': 325,
#             'name': 'channel_number',
#             'nodeType': 'Identifier',
#             'overloadedDeclarations': [],
#             'referencedDeclaration': 315,
#             'src': '1851:14:3',
#             'typeDescriptions': {'typeIdentifier': 't_uint256',
#              'typeString': 'uint256'}},
#            'nodeType': 'BinaryOperation',
#            'operator': '+',
#            'rightExpression': {'argumentTypes': None,
#             'hexValue': '31',
#             'id': 326,
#             'isConstant': False,
#             'isLValue': False,
#             'isPure': True,
#             'kind': 'number',
#             'lValueRequested': False,
#             'nodeType': 'Literal',
#             'src': '1868:1:3',
#             'subdenomination': None,
#             'typeDescriptions': {'typeIdentifier': 't_rational_1_by_1',
#              'typeString': 'int_const 1'},
#             'value': '1'},
#            'src': '1851:18:3',
#            'typeDescriptions': {'typeIdentifier': 't_uint256',
#             'typeString': 'uint256'}},
#           'src': '1819:50:3',
#           'typeDescriptions': {'typeIdentifier': 't_uint256',
#            'typeString': 'uint256'}},
#          'id': 329,
#          'nodeType': 'ExpressionStatement',
#          'src': '1819:50:3'},
#         {'expression': {'argumentTypes': None,
#           'id': 343,
#           'isConstant': False,
#           'isLValue': False,
#           'isPure': False,
#           'lValueRequested': False,
#           'leftHandSide': {'argumentTypes': None,
#            'baseExpression': {'argumentTypes': None,
#             'baseExpression': {'argumentTypes': None,
#              'id': 330,
#              'name': 'state',
#              'nodeType': 'Identifier',
#              'overloadedDeclarations': [],
#              'referencedDeclaration': 267,
#              'src': '1879:5:3',
#              'typeDescriptions': {'typeIdentifier': 't_mapping$_t_address_$_t_mapping$_t_uint256_$_t_struct$_StateS_$257_storage_$_$',
#               'typeString': 'mapping(address => mapping(uint256 => struct StateChannel.StateS storage ref))'}},
#             'id': 334,
#             'indexExpression': {'argumentTypes': None,
#              'expression': {'argumentTypes': None,
#               'id': 331,
#               'name': 'msg',
#               'nodeType': 'Identifier',
#               'overloadedDeclarations': [],
#               'referencedDeclaration': 741,
#               'src': '1885:3:3',
#               'typeDescriptions': {'typeIdentifier': 't_magic_message',
#                'typeString': 'msg'}},
#              'id': 332,
#              'isConstant': False,
#              'isLValue': False,
#              'isPure': False,
#              'lValueRequested': False,
#              'memberName': 'sender',
#              'nodeType': 'MemberAccess',
#              'referencedDeclaration': None,
#              'src': '1885:10:3',
#              'typeDescriptions': {'typeIdentifier': 't_address',
#               'typeString': 'address'}},
#             'isConstant': False,
#             'isLValue': True,
#             'isPure': False,
#             'lValueRequested': False,
#             'nodeType': 'IndexAccess',
#             'src': '1879:17:3',
#             'typeDescriptions': {'typeIdentifier': 't_mapping$_t_uint256_$_t_struct$_StateS_$257_storage_$',
#              'typeString': 'mapping(uint256 => struct StateChannel.StateS storage ref)'}},
#            'id': 335,
#            'indexExpression': {'argumentTypes': None,
#             'id': 333,
#             'name': 'channel_number',
#             'nodeType': 'Identifier',
#             'overloadedDeclarations': [],
#             'referencedDeclaration': 315,
#             'src': '1897:14:3',
#             'typeDescriptions': {'typeIdentifier': 't_uint256',
#              'typeString': 'uint256'}},
#            'isConstant': False,
#            'isLValue': True,
#            'isPure': False,
#            'lValueRequested': True,
#            'nodeType': 'IndexAccess',
#            'src': '1879:33:3',
#            'typeDescriptions': {'typeIdentifier': 't_struct$_StateS_$257_storage',
#             'typeString': 'struct StateChannel.StateS storage ref'}},
#           'nodeType': 'Assignment',
#           'operator': '=',
#           'rightHandSide': {'argumentTypes': None,
#            'arguments': [{'argumentTypes': None,
#              'expression': {'argumentTypes': None,
#               'id': 337,
#               'name': 'Stage',
#               'nodeType': 'Identifier',
#               'overloadedDeclarations': [],
#               'referencedDeclaration': 248,
#               'src': '1943:5:3',
#               'typeDescriptions': {'typeIdentifier': 't_type$_t_enum$_Stage_$248_$',
#                'typeString': 'type(enum StateChannel.Stage)'}},
#              'id': 338,
#              'isConstant': False,
#              'isLValue': False,
#              'isPure': True,
#              'lValueRequested': False,
#              'memberName': 'Open',
#              'nodeType': 'MemberAccess',
#              'referencedDeclaration': None,
#              'src': '1943:10:3',
#              'typeDescriptions': {'typeIdentifier': 't_enum$_Stage_$248',
#               'typeString': 'enum StateChannel.Stage'}},
#             {'argumentTypes': None,
#              'id': 339,
#              'name': 'cap',
#              'nodeType': 'Identifier',
#              'overloadedDeclarations': [],
#              'referencedDeclaration': 299,
#              'src': '1973:3:3',
#              'typeDescriptions': {'typeIdentifier': 't_uint256',
#               'typeString': 'uint256'}},
#             {'argumentTypes': None,
#              'hexValue': '30',
#              'id': 340,
#              'isConstant': False,
#              'isLValue': False,
#              'isPure': True,
#              'kind': 'number',
#              'lValueRequested': False,
#              'nodeType': 'Literal',
#              'src': '2001:1:3',
#              'subdenomination': None,
#              'typeDescriptions': {'typeIdentifier': 't_rational_0_by_1',
#               'typeString': 'int_const 0'},
#              'value': '0'},
#             {'argumentTypes': None,
#              'hexValue': '30',
#              'id': 341,
#              'isConstant': False,
#              'isLValue': False,
#              'isPure': True,
#              'kind': 'number',
#              'lValueRequested': False,
#              'nodeType': 'Literal',
#              'src': '2028:1:3',
#              'subdenomination': None,
#              'typeDescriptions': {'typeIdentifier': 't_rational_0_by_1',
#               'typeString': 'int_const 0'},
#              'value': '0'}],
#            'expression': {'argumentTypes': None,
#             'id': 336,
#             'name': 'StateS',
#             'nodeType': 'Identifier',
#             'overloadedDeclarations': [],
#             'referencedDeclaration': 257,
#             'src': '1915:6:3',
#             'typeDescriptions': {'typeIdentifier': 't_type$_t_struct$_StateS_$257_storage_ptr_$',
#              'typeString': 'type(struct StateChannel.StateS storage pointer)'}},
#            'id': 342,
#            'isConstant': False,
#            'isLValue': False,
#            'isPure': False,
#            'kind': 'structConstructorCall',
#            'lValueRequested': False,
#            'names': ['stage', 'cap', 'closed_at', 'funds_used'],
#            'nodeType': 'FunctionCall',
#            'src': '1915:125:3',
#            'typeDescriptions': {'typeIdentifier': 't_struct$_StateS_$257_memory',
#             'typeString': 'struct StateChannel.StateS memory'}},
#           'src': '1879:161:3',
#           'typeDescriptions': {'typeIdentifier': 't_struct$_StateS_$257_storage',
#            'typeString': 'struct StateChannel.StateS storage ref'}},
#          'id': 344,
#          'nodeType': 'ExpressionStatement',
#          'src': '1879:161:3'},
#         {'eventCall': {'argumentTypes': None,
#           'arguments': [{'argumentTypes': None,
#             'expression': {'argumentTypes': None,
#              'id': 346,
#              'name': 'msg',
#              'nodeType': 'Identifier',
#              'overloadedDeclarations': [],
#              'referencedDeclaration': 741,
#              'src': '2071:3:3',
#              'typeDescriptions': {'typeIdentifier': 't_magic_message',
#               'typeString': 'msg'}},
#             'id': 347,
#             'isConstant': False,
#             'isLValue': False,
#             'isPure': False,
#             'lValueRequested': False,
#             'memberName': 'sender',
#             'nodeType': 'MemberAccess',
#             'referencedDeclaration': None,
#             'src': '2071:10:3',
#             'typeDescriptions': {'typeIdentifier': 't_address',
#              'typeString': 'address'}},
#            {'argumentTypes': None,
#             'id': 348,
#             'name': 'channel_number',
#             'nodeType': 'Identifier',
#             'overloadedDeclarations': [],
#             'referencedDeclaration': 315,
#             'src': '2083:14:3',
#             'typeDescriptions': {'typeIdentifier': 't_uint256',
#              'typeString': 'uint256'}},
#            {'argumentTypes': None,
#             'id': 349,
#             'name': 'cap',
#             'nodeType': 'Identifier',
#             'overloadedDeclarations': [],
#             'referencedDeclaration': 299,
#             'src': '2099:3:3',
#             'typeDescriptions': {'typeIdentifier': 't_uint256',
#              'typeString': 'uint256'}}],
#           'expression': {'argumentTypes': [{'typeIdentifier': 't_address',
#              'typeString': 'address'},
#             {'typeIdentifier': 't_uint256', 'typeString': 'uint256'},
#             {'typeIdentifier': 't_uint256', 'typeString': 'uint256'}],
#            'id': 345,
#            'name': 'CreatedChannel',
#            'nodeType': 'Identifier',
#            'overloadedDeclarations': [],
#            'referencedDeclaration': 275,
#            'src': '2056:14:3',
#            'typeDescriptions': {'typeIdentifier': 't_function_event_nonpayable$_t_address_$_t_uint256_$_t_uint256_$returns$__$',
#             'typeString': 'function (address,uint256,uint256)'}},
#           'id': 350,
#           'isConstant': False,
#           'isLValue': False,
#           'isPure': False,
#           'kind': 'functionCall',
#           'lValueRequested': False,
#           'names': [],
#           'nodeType': 'FunctionCall',
#           'src': '2056:47:3',
#           'typeDescriptions': {'typeIdentifier': 't_tuple$__$',
#            'typeString': 'tuple()'}},
#          'id': 351,
#          'nodeType': 'EmitStatement',
#          'src': '2051:52:3'},
#         {'expression': {'argumentTypes': None,
#           'id': 352,
#           'name': 'channel_number',
#           'nodeType': 'Identifier',
#           'overloadedDeclarations': [],
#           'referencedDeclaration': 315,
#           'src': '2120:14:3',
#           'typeDescriptions': {'typeIdentifier': 't_uint256',
#            'typeString': 'uint256'}},
#          'functionReturnParameters': 303,
#          'id': 353,
#          'nodeType': 'Return',
#          'src': '2113:21:3'}]},
#       'documentation': None,
#       'id': 355,
#       'implemented': True,
#       'isConstructor': False,
#       'isDeclaredConst': False,
#       'modifiers': [],
#       'name': 'createNewChannel',
#       'nodeType': 'FunctionDefinition',
#       'parameters': {'id': 300,
#        'nodeType': 'ParameterList',
#        'parameters': [{'constant': False,
#          'id': 299,
#          'name': 'cap',
#          'nodeType': 'VariableDeclaration',
#          'scope': 355,
#          'src': '1603:11:3',
#          'stateVariable': False,
#          'storageLocation': 'default',
#          'typeDescriptions': {'typeIdentifier': 't_uint256',
#           'typeString': 'uint256'},
#          'typeName': {'id': 298,
#           'name': 'uint256',
#           'nodeType': 'ElementaryTypeName',
#           'src': '1603:7:3',
#           'typeDescriptions': {'typeIdentifier': 't_uint256',
#            'typeString': 'uint256'}},
#          'value': None,
#          'visibility': 'internal'}],
#        'src': '1602:13:3'},
#       'payable': True,
#       'returnParameters': {'id': 303,
#        'nodeType': 'ParameterList',
#        'parameters': [{'constant': False,
#          'id': 302,
#          'name': '',
#          'nodeType': 'VariableDeclaration',
#          'scope': 355,
#          'src': '1639:7:3',
#          'stateVariable': False,
#          'storageLocation': 'default',
#          'typeDescriptions': {'typeIdentifier': 't_uint256',
#           'typeString': 'uint256'},
#          'typeName': {'id': 301,
#           'name': 'uint256',
#           'nodeType': 'ElementaryTypeName',
#           'src': '1639:7:3',
#           'typeDescriptions': {'typeIdentifier': 't_uint256',
#            'typeString': 'uint256'}},
#          'value': None,
#          'visibility': 'internal'}],
#        'src': '1638:9:3'},
#       'scope': 726,
#       'src': '1577:564:3',
#       'stateMutability': 'payable',
#       'superFunction': None,
#       'visibility': 'public'},
#      {'body': {'id': 401,
#        'nodeType': 'Block',
#        'src': '2227:257:3',
#        'statements': [{'assignments': [363],
#          'declarations': [{'constant': False,
#            'id': 363,
#            'name': 'st',
#            'nodeType': 'VariableDeclaration',
#            'scope': 402,
#            'src': '2237:17:3',
#            'stateVariable': False,
#            'storageLocation': 'storage',
#            'typeDescriptions': {'typeIdentifier': 't_struct$_StateS_$257_storage_ptr',
#             'typeString': 'struct StateChannel.StateS'},
#            'typeName': {'contractScope': None,
#             'id': 362,
#             'name': 'StateS',
#             'nodeType': 'UserDefinedTypeName',
#             'referencedDeclaration': 257,
#             'src': '2237:6:3',
#             'typeDescriptions': {'typeIdentifier': 't_struct$_StateS_$257_storage_ptr',
#              'typeString': 'struct StateChannel.StateS'}},
#            'value': None,
#            'visibility': 'internal'}],
#          'id': 370,
#          'initialValue': {'argumentTypes': None,
#           'baseExpression': {'argumentTypes': None,
#            'baseExpression': {'argumentTypes': None,
#             'id': 364,
#             'name': 'state',
#             'nodeType': 'Identifier',
#             'overloadedDeclarations': [],
#             'referencedDeclaration': 267,
#             'src': '2257:5:3',
#             'typeDescriptions': {'typeIdentifier': 't_mapping$_t_address_$_t_mapping$_t_uint256_$_t_struct$_StateS_$257_storage_$_$',
#              'typeString': 'mapping(address => mapping(uint256 => struct StateChannel.StateS storage ref))'}},
#            'id': 367,
#            'indexExpression': {'argumentTypes': None,
#             'expression': {'argumentTypes': None,
#              'id': 365,
#              'name': 'msg',
#              'nodeType': 'Identifier',
#              'overloadedDeclarations': [],
#              'referencedDeclaration': 741,
#              'src': '2263:3:3',
#              'typeDescriptions': {'typeIdentifier': 't_magic_message',
#               'typeString': 'msg'}},
#             'id': 366,
#             'isConstant': False,
#             'isLValue': False,
#             'isPure': False,
#             'lValueRequested': False,
#             'memberName': 'sender',
#             'nodeType': 'MemberAccess',
# ...
#            'typeName': {'id': 702,
#             'name': 'bytes',
#             'nodeType': 'ElementaryTypeName',
#             'src': '5166:5:3',
#             'typeDescriptions': {'typeIdentifier': 't_bytes_storage_ptr',
#              'typeString': 'bytes'}},
#            'value': None,
#            'visibility': 'internal'}],
#          'id': 705,
#          'initialValue': {'argumentTypes': None,
#           'hexValue': '19457468657265756d205369676e6564204d6573736167653a0a3332',
#           'id': 704,
#           'isConstant': False,
#           'isLValue': False,
#           'isPure': True,
#           'kind': 'string',
#           'lValueRequested': False,
#           'nodeType': 'Literal',
#           'src': '5188:34:3',
#           'subdenomination': None,
#           'typeDescriptions': {'typeIdentifier': 't_stringliteral_178a2411ab6fbc1ba11064408972259c558d0e82fd48b0aba3ad81d14f065e73',
#            'typeString': 'literal_string "\x19Ethereum Signed Message:\n32"'},
#           'value': '\x19Ethereum Signed Message:\n32'},
#          'nodeType': 'VariableDeclarationStatement',
#          'src': '5166:56:3'},
#         {'assignments': [707],
#          'declarations': [{'constant': False,
#            'id': 707,
#            'name': 'prefixedHash',
#            'nodeType': 'VariableDeclaration',
#            'scope': 725,
#            'src': '5232:20:3',
#            'stateVariable': False,
#            'storageLocation': 'default',
#            'typeDescriptions': {'typeIdentifier': 't_bytes32',
#             'typeString': 'bytes32'},
#            'typeName': {'id': 706,
#             'name': 'bytes32',
#             'nodeType': 'ElementaryTypeName',
#             'src': '5232:7:3',
#             'typeDescriptions': {'typeIdentifier': 't_bytes32',
#              'typeString': 'bytes32'}},
#            'value': None,
#            'visibility': 'internal'}],
#          'id': 712,
#          'initialValue': {'argumentTypes': None,
#           'arguments': [{'argumentTypes': None,
#             'id': 709,
#             'name': 'prefix',
#             'nodeType': 'Identifier',
#             'overloadedDeclarations': [],
#             'referencedDeclaration': 703,
#             'src': '5260:6:3',
#             'typeDescriptions': {'typeIdentifier': 't_bytes_memory_ptr',
#              'typeString': 'bytes memory'}},
#            {'argumentTypes': None,
#             'id': 710,
#             'name': 'message',
#             'nodeType': 'Identifier',
#             'overloadedDeclarations': [],
#             'referencedDeclaration': 691,
#             'src': '5268:7:3',
#             'typeDescriptions': {'typeIdentifier': 't_bytes32',
#              'typeString': 'bytes32'}}],
#           'expression': {'argumentTypes': [{'typeIdentifier': 't_bytes_memory_ptr',
#              'typeString': 'bytes memory'},
#             {'typeIdentifier': 't_bytes32', 'typeString': 'bytes32'}],
#            'id': 708,
#            'name': 'sha3',
#            'nodeType': 'Identifier',
#            'overloadedDeclarations': [],
#            'referencedDeclaration': 751,
#            'src': '5255:4:3',
#            'typeDescriptions': {'typeIdentifier': 't_function_sha3_pure$__$returns$_t_bytes32_$',
#             'typeString': 'function () pure returns (bytes32)'}},
#           'id': 711,
#           'isConstant': False,
#           'isLValue': False,
#           'isPure': False,
#           'kind': 'functionCall',
#           'lValueRequested': False,
#           'names': [],
#           'nodeType': 'FunctionCall',
#           'src': '5255:21:3',
#           'typeDescriptions': {'typeIdentifier': 't_bytes32',
#            'typeString': 'bytes32'}},
#          'nodeType': 'VariableDeclarationStatement',
#          'src': '5232:44:3'},
#         {'assignments': [714],
#          'declarations': [{'constant': False,
#            'id': 714,
#            'name': 'addr',
#            'nodeType': 'VariableDeclaration',
#            'scope': 725,
#            'src': '5286:12:3',
#            'stateVariable': False,
#            'storageLocation': 'default',
#            'typeDescriptions': {'typeIdentifier': 't_address',
#             'typeString': 'address'},
#            'typeName': {'id': 713,
#             'name': 'address',
#             'nodeType': 'ElementaryTypeName',
#             'src': '5286:7:3',
#             'typeDescriptions': {'typeIdentifier': 't_address',
#              'typeString': 'address'}},
#            'value': None,
#            'visibility': 'internal'}],
#          'id': 721,
#          'initialValue': {'argumentTypes': None,
#           'arguments': [{'argumentTypes': None,
#             'id': 716,
#             'name': 'prefixedHash',
#             'nodeType': 'Identifier',
#             'overloadedDeclarations': [],
#             'referencedDeclaration': 707,
#             'src': '5311:12:3',
#             'typeDescriptions': {'typeIdentifier': 't_bytes32',
#              'typeString': 'bytes32'}},
#            {'argumentTypes': None,
#             'id': 717,
#             'name': 'v',
#             'nodeType': 'Identifier',
#             'overloadedDeclarations': [],
#             'referencedDeclaration': 693,
#             'src': '5325:1:3',
#             'typeDescriptions': {'typeIdentifier': 't_uint8',
#              'typeString': 'uint8'}},
#            {'argumentTypes': None,
#             'id': 718,
#             'name': 'r',
#             'nodeType': 'Identifier',
#             'overloadedDeclarations': [],
#             'referencedDeclaration': 695,
#             'src': '5328:1:3',
#             'typeDescriptions': {'typeIdentifier': 't_bytes32',
#              'typeString': 'bytes32'}},
#            {'argumentTypes': None,
#             'id': 719,
#             'name': 's',
#             'nodeType': 'Identifier',
#             'overloadedDeclarations': [],
#             'referencedDeclaration': 697,
#             'src': '5331:1:3',
#             'typeDescriptions': {'typeIdentifier': 't_bytes32',
#              'typeString': 'bytes32'}}],
#           'expression': {'argumentTypes': [{'typeIdentifier': 't_bytes32',
#              'typeString': 'bytes32'},
#             {'typeIdentifier': 't_uint8', 'typeString': 'uint8'},
#             {'typeIdentifier': 't_bytes32', 'typeString': 'bytes32'},
#             {'typeIdentifier': 't_bytes32', 'typeString': 'bytes32'}],
#            'id': 715,
#            'name': 'ecrecover',
#            'nodeType': 'Identifier',
#            'overloadedDeclarations': [],
#            'referencedDeclaration': 733,
#            'src': '5301:9:3',
#            'typeDescriptions': {'typeIdentifier': 't_function_ecrecover_pure$_t_bytes32_$_t_uint8_$_t_bytes32_$_t_bytes32_$returns$_t_address_$',
#             'typeString': 'function (bytes32,uint8,bytes32,bytes32) pure returns (address)'}},
#           'id': 720,
#           'isConstant': False,
#           'isLValue': False,
#           'isPure': False,
#           'kind': 'functionCall',
#           'lValueRequested': False,
#           'names': [],
#           'nodeType': 'FunctionCall',
#           'src': '5301:32:3',
#           'typeDescriptions': {'typeIdentifier': 't_address',
#            'typeString': 'address'}},
#          'nodeType': 'VariableDeclarationStatement',
#          'src': '5286:47:3'},
#         {'expression': {'argumentTypes': None,
#           'id': 722,
#           'name': 'addr',
#           'nodeType': 'Identifier',
#           'overloadedDeclarations': [],
#           'referencedDeclaration': 714,
#           'src': '5350:4:3',
#           'typeDescriptions': {'typeIdentifier': 't_address',
#            'typeString': 'address'}},
#          'functionReturnParameters': 701,
#          'id': 723,
#          'nodeType': 'Return',
#          'src': '5343:11:3'}]},
#       'documentation': None,
#       'id': 725,
#       'implemented': True,
#       'isConstructor': False,
#       'isDeclaredConst': True,
#       'modifiers': [],
#       'name': 'verify',
#       'nodeType': 'FunctionDefinition',
#       'parameters': {'id': 698,
#        'nodeType': 'ParameterList',
#        'parameters': [{'constant': False,
#          'id': 691,
#          'name': 'message',
#          'nodeType': 'VariableDeclaration',
#          'scope': 725,
#          'src': '5079:15:3',
#          'stateVariable': False,
#          'storageLocation': 'default',
#          'typeDescriptions': {'typeIdentifier': 't_bytes32',
#           'typeString': 'bytes32'},
#          'typeName': {'id': 690,
#           'name': 'bytes32',
#           'nodeType': 'ElementaryTypeName',
#           'src': '5079:7:3',
#           'typeDescriptions': {'typeIdentifier': 't_bytes32',
#            'typeString': 'bytes32'}},
#          'value': None,
#          'visibility': 'internal'},
#         {'constant': False,
#          'id': 693,
#          'name': 'v',
#          'nodeType': 'VariableDeclaration',
#          'scope': 725,
#          'src': '5096:7:3',
#          'stateVariable': False,
#          'storageLocation': 'default',
#          'typeDescriptions': {'typeIdentifier': 't_uint8',
#           'typeString': 'uint8'},
#          'typeName': {'id': 692,
#           'name': 'uint8',
#           'nodeType': 'ElementaryTypeName',
#           'src': '5096:5:3',
#           'typeDescriptions': {'typeIdentifier': 't_uint8',
#            'typeString': 'uint8'}},
#          'value': None,
#          'visibility': 'internal'},
#         {'constant': False,
#          'id': 695,
#          'name': 'r',
#          'nodeType': 'VariableDeclaration',
#          'scope': 725,
#          'src': '5105:9:3',
#          'stateVariable': False,
#          'storageLocation': 'default',
#          'typeDescriptions': {'typeIdentifier': 't_bytes32',
#           'typeString': 'bytes32'},
#          'typeName': {'id': 694,
#           'name': 'bytes32',
#           'nodeType': 'ElementaryTypeName',
#           'src': '5105:7:3',
#           'typeDescriptions': {'typeIdentifier': 't_bytes32',
#            'typeString': 'bytes32'}},
#          'value': None,
#          'visibility': 'internal'},
#         {'constant': False,
#          'id': 697,
#          'name': 's',
#          'nodeType': 'VariableDeclaration',
#          'scope': 725,
#          'src': '5116:9:3',
#          'stateVariable': False,
#          'storageLocation': 'default',
#          'typeDescriptions': {'typeIdentifier': 't_bytes32',
#           'typeString': 'bytes32'},
#          'typeName': {'id': 696,
#           'name': 'bytes32',
#           'nodeType': 'ElementaryTypeName',
#           'src': '5116:7:3',
#           'typeDescriptions': {'typeIdentifier': 't_bytes32',
#            'typeString': 'bytes32'}},
#          'value': None,
#          'visibility': 'internal'}],
#        'src': '5078:48:3'},
#       'payable': False,
#       'returnParameters': {'id': 701,
#        'nodeType': 'ParameterList',
#        'parameters': [{'constant': False,
#          'id': 700,
#          'name': '',
#          'nodeType': 'VariableDeclaration',
#          'scope': 725,
#          'src': '5147:7:3',
#          'stateVariable': False,
#          'storageLocation': 'default',
#          'typeDescriptions': {'typeIdentifier': 't_address',
#           'typeString': 'address'},
#          'typeName': {'id': 699,
#           'name': 'address',
#           'nodeType': 'ElementaryTypeName',
#           'src': '5147:7:3',
#           'typeDescriptions': {'typeIdentifier': 't_address',
#            'typeString': 'address'}},
#          'value': None,
#          'visibility': 'internal'}],
#        'src': '5146:9:3'},
#       'scope': 726,
#       'src': '5063:298:3',
#       'stateMutability': 'pure',
#       'superFunction': None,
#       'visibility': 'public'}],
#     'scope': 727,
#     'src': '272:5091:3'}],
#   'src': '0:5363:3'},
#  'networks': {'5777': {'address': '0xd812af350248869ded1cc6342dd2caf920515f10',
#    'events': {},
#    'links': {},
#    'transactionHash': '0xabc982fc0012378b0248ac2b47ba5638063435e09f6875f778982abebd71615e'}},
#  'schemaVersion': '2.0.0',
#  'source': 'pragma solidity ^0.4.23;\n\n// import \'https://github.com/OpenZeppelin/openzeppelin-solidity/contracts/ownership/Ownable.sol\';\n// import \'https://github.com/OpenZeppelin/openzeppelin-solidity/contracts/math/SafeMath.sol\';\n\nimport \'./Ownable.sol\';\nimport \'./SafeMath.sol\';\n\n\ncontract StateChannel is Ownable {\n\n\tusing SafeMath for uint256; // TODO\n\n    uint256 public constant PUNISHMENT = 1 ether;  // TODO should be ~10% of value - solidity doesnt have floats, so better to do it that way\n    uint256 public constant WAITING_PERIOD = 3; // 4 * 2880;  // after "close" call, we\'re waiting ~48h for challenge (new block appears - on average - every 15 seconds)\n    bool public accepting_new_channels = true;\n\n    enum Stage {\n        Open,\n        WaitingForChallengeByOwner,\n        Closed\n    }\n\n    struct StateS {\n        Stage stage;\n        uint256 cap;\n        uint256 closed_at;\n        uint256 funds_used;\n    }\n\n    mapping (address => uint256) available_channel; // since one user can have multiple channels, this mapping holds the minimal available number\n    mapping (address => mapping (uint256 => StateS)) state;  // the client is responsible for remembering the number - he get\'s it after initialization\n\n    event CreatedChannel(address user, uint256 channel_number, uint256 cap);\n\n    constructor(bool _accepting_new_channels) public payable {\n        changeAcceptanceStatus(_accepting_new_channels);\n    }\n\n    function changeAcceptanceStatus(bool _accepting_new_channels) public onlyOwner {\n        accepting_new_channels = _accepting_new_channels;\n    }\n\n    function createNewChannel(uint256 cap) public payable returns(uint256) {\n        require (msg.value == (cap + PUNISHMENT));\n        // require (accepting_new_channels);\n\n        uint256 channel_number = available_channel[msg.sender];\n        available_channel[msg.sender] = channel_number + 1;\n        state[msg.sender][channel_number] = StateS({\n            stage: Stage.Open, \n            cap: cap,\n            closed_at: 0,\n            funds_used: 0\n        });\n\n        emit CreatedChannel(msg.sender, channel_number, cap);\n        return channel_number;\n    }\n\n    function startClosingByUser (uint256 channel_number, uint256 funds_used) public {\n        StateS storage st = state[msg.sender][channel_number];\n\n        require (st.stage == Stage.Open);\n\n        st.funds_used = funds_used;\n        st.closed_at = block.number + WAITING_PERIOD;\n        st.stage = Stage.WaitingForChallengeByOwner;\n    }\n\n    function closeByOwner (\n        address user, \n        uint256 channel_number, \n        uint256 funds_used, \n        uint8 v, \n        bytes32 r, \n        bytes32 s) public onlyOwner {\n        StateS storage st = state[user][channel_number];\n\n        require (st.stage == Stage.Open);\n        require (verifyReceipt(funds_used, user, channel_number, v, r, s));\n        \n        st.stage = Stage.Closed;\n\n        uint256 funds_left = st.cap - funds_used;\n        \n        owner.transfer(funds_used);\n        user.transfer(funds_left + PUNISHMENT);  // return PUNISHMENT to user, since he didn\'t cheat\n    }\n    \n    function challengeByOwner (address user, \n        uint256 channel_number, \n        uint256 funds_used, \n        uint8 v, \n        bytes32 r, \n        bytes32 s) public {\n    \tStateS storage st = state[user][channel_number];\n\n    \trequire (st.stage == Stage.WaitingForChallengeByOwner);\n    \trequire (st.funds_used < funds_used);  // we can only challenge if we propose higher funds_used\n    \trequire (st.cap >= funds_used); // and we can only propose lower funds than cap\n        require (verifyReceipt(funds_used, user, channel_number, v, r, s));\n\n        st.stage = Stage.Closed;\n        \n        // It appears owner is right - user should then pay PUNISHMENT and return funds to user\n        uint256 funds_left = st.cap - funds_used;\n        \n        owner ...
#  'sourceMap': '272:5091:3:-;;;699:4;662:41;;;;;;;;;;;;;;;;;;;;1300:121;;;;;;;;;;;;;;;;;;;;;;;;;;;;575:10:1;567:5;;:18;;;;;;;;;;;;;;;;;;1367:47:3;1390:23;1367:22;;;:47;;;:::i;:::-;1300:121;272:5091;;1427:144;719:5:1;;;;;;;;;;;705:19;;:10;:19;;;697:28;;;;;;;;1541:23:3;1516:22;;:48;;;;;;;;;;;;;;;;;;1427:144;:::o;272:5091::-;;;;;;;',
#  'sourcePath': '/home/jack/eth_labs/code/project/truffle/contracts/StateChannel.sol',
#  'updatedAt': '2018-06-03T06:32:53.727Z'}

# %%
address = contract_abi[]

# %%
cnt = w3.eth.contract(address=address, abi=contract_abi)

# %%
owner = c(cnt.functions.owner().call())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-e716eb40bc35> in <module>()
# ----> 1 owner = c(cnt.functions.owner().call())
#
# /home/jack/anaconda3/lib/python3.6/site-packages/web3/contract.py in call(self, transaction, block_identifier)
#    1029                                       block_id,
#    1030                                       *self.args,
# -> 1031                                       **self.kwargs)
#    1032
#    1033     def transact(self, transaction=None):
#
# /home/jack/anaconda3/lib/python3.6/site-packages/web3/contract.py in call_contract_function(abi, web3, address, normalizers, function_identifier, transaction, block_id, *args, **kwargs)
#    1260         return_data = web3.eth.call(call_transaction)
#    1261     else:
# -> 1262         return_data = web3.eth.call(call_transaction, block_identifier=block_id)
#    1263
#    1264     function_abi = find_matching_fn_abi(abi, function_identifier, args, kwargs)
#
# /home/jack/anaconda3/lib/python3.6/site-packages/eth_utils/functional.py in inner(*args, **kwargs)
#      20         @functools.wraps(fn)
#      21         def inner(*args, **kwargs):
# ---> 22             return callback(fn(*args, **kwargs))
#      23
#      24         return inner
#
# /home/jack/anaconda3/lib/python3.6/site-packages/web3/eth.py in call(self, transaction, block_identifier)
#     268         return self.web3.manager.request_blocking(
#     269             "eth_call",
# --> 270             [transaction, block_identifier],
#     271         )
#     272
#
# /home/jack/anaconda3/lib/python3.6/site-packages/web3/manager.py in request_blocking(self, method, params)
#     104
#     105         if "error" in response:
# --> 106             raise ValueError(response["error"])
#     107
#     108         return response['result']
#
# ValueError: {'message': 'Attempting to run transaction which calls a contract function, but recipient address 0x9A9ed333eAc0Ed9705A814E69471701d1f43d9Fe is not a contract address', 'code': -32000, 'data': {'stack': 'n: Attempting to run transaction which calls a contract function, but recipient address 0x9A9ed333eAc0Ed9705A814E69471701d1f43d9Fe is not a contract address\n    at /home/jack/Programs/node-v9.11.1-linux-x64/lib/node_modules/ganache-cli/build/cli.node.js:2:4080985\n    at /home/jack/Programs/node-v9.11.1-linux-x64/lib/node_modules/ganache-cli/build/cli.node.js:2:4072925\n    at /home/jack/Programs/node-v9.11.1-linux-x64/lib/node_modules/ganache-cli/build/cli.node.js:2:542986\n    at e.exports.c.getCode (/home/jack/Programs/node-v9.11.1-linux-x64/lib/node_modules/ganache-cli/build/cli.node.js:2:120503)\n    at /home/jack/Programs/node-v9.11.1-linux-x64/lib/node_modules/ganache-cli/build/cli.node.js:2:542936\n    at /home/jack/Programs/node-v9.11.1-linux-x64/lib/node_modules/ganache-cli/build/cli.node.js:2:4050264\n    at /home/jack/Programs/node-v9.11.1-linux-x64/lib/node_modules/ganache-cli/build/cli.node.js:2:4053943\n    at Object.return (/home/jack/Programs/node-v9.11.1-linux-x64/lib/node_modules/ganache-cli/build/cli.node.js:2:4053602)\n    at /home/jack/Programs/node-v9.11.1-linux-x64/lib/node_modules/ganache-cli/build/cli.node.js:2:4051854\n    at e (/home/jack/Programs/node-v9.11.1-linux-x64/lib/node_modules/ganache-cli/build/cli.node.js:2:4053891)\n    at /home/jack/Programs/node-v9.11.1-linux-x64/lib/node_modules/ganache-cli/build/cli.node.js:2:4053902\n    at /home/jack/Programs/node-v9.11.1-linux-x64/lib/node_modules/ganache-cli/build/cli.node.js:2:4051066\n    at process._tickCallback (internal/process/next_tick.js:176:11)', 'name': 'n'}}

# %%
cnt.functions.accepting_new_channels().call()

transact_params = {"from": owner}

fs = cnt.transact(transact_params).changeAcceptanceStatus(False)

# %%
w3.eth.waitForTransactionReceipt(fs)
# Out:
# AttributeDict({'blockHash': HexBytes('0x1912273bde52fbbfbff55a6483b592e35c107c562aa0da37fab1bdc4e7c88003'),
#  'blockNumber': 7,
#  'contractAddress': None,
#  'cumulativeGasUsed': 27212,
#  'gasUsed': 27212,
#  'logs': [],
#  'logsBloom': HexBytes('...'),
#  'status': 1,
#  'transactionHash': HexBytes('0x2a76e515ea3910079dbf2f4b88e5ec9d7df384f9826e14297c4552f4f0119b7d'),
#  'transactionIndex': 0})

# %%
cnt.functions.accepting_new_channels().call()
# Out:
# False

# %%
msg = w3.sha3(text="Hello")
signature = w3.eth.sign(owner, msg)

signature = signature.hex()

r = signature[:66]
s = '0x' + signature[66:130]
v = '0x' + signature[130:132]
v = int(v, 16)
v = v if v in [27, 28] else v + 27

r,s,v
# Out:
# ('0xb2042d4cb731657d76e75d14adfe9c84f7697023625cc884eae9d8cd8d8b5fc5',
#  '0x7dcaabdfaa034d1b87cf42669533dee0d28d6155747737834841b6490d4acf1f',
#  28)

# %%
accs  =w3.eth.accounts
# Out:
# ['0xd1687a6295283061450ac168f5C03e309BB9CDc4',
#  '0xE58ea859e7DE7EaB1328A730CB397d9597F5aDC6',
#  '0xbE72827E14f5B4C643A99c350D5842254b48E49b',
#  '0x8629072578e020816EdeaB88BF1B17614B8eEAfa',
#  '0x62468469D0b487301B6bA250Ca9fC57403104c1d',
#  '0x4BBc60396Af5BabCFC59AA36209Fff06B8BD0d8a',
#  '0xD2b36a08569cc94BA535821327D747DE4DB4f024',
#  '0xa145721c142Edf54b9c475728347D00878009186',
#  '0xBaCC6458029d29f7a04aAA48530013eFa11c7D39',
#  '0x802edcc41Cce931045A3A34195c65C41215E09Bd']
